# %% [markdown]
# #**Shop Customer Data**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = '/content/drive/MyDrive/POSTEST1_AVD/Customers.csv'
df = pd.read_csv(file)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %% [markdown]
# # AVD_Ahmad Fajar Novia_041

# %% [markdown]
# ##BISNIS UNDERSTANDING

# %% [markdown]
# ###**Business Objective**

# %% [markdown]
# Dataset pelanggan ini diperoleh dari sistem kartu keanggotaan yang diterapkan oleh sebuah toko tertentu. Data mencakup 2000 pelanggan dengan delapan variabel yang menggambarkan karakteristik demografis dan ekonomi, seperti usia, pendapatan tahunan, profesi, lama pengalaman kerja, jumlah anggota keluarga, serta Spending Score yang merepresentasikan perilaku dan pola pengeluaran pelanggan.
#
# Tujuan utama analisis ini adalah meningkatkan pendapatan toko dengan mengidentifikasi serta memahami segmen pelanggan yang memiliki tingkat pengeluaran tinggi. Melalui pengolahan dan analisisnya, karakteristik serta perilaku pelanggan berdasarkan data yang tersedia, diharapkan dapat ditemukan kelompok pelanggan paling potensial. Hasil analisis tersebut akan membantu pihak toko dalam menentukan target pasar secara lebih tepat, sehingga strategi pemasaran difokuskan pada pelanggan yang memberikan kontribusi pendapatan terbesar.

# %% [markdown]
# ###**Assess Situation**

# %% [markdown]
# Dalam kondisi dataset ini ditemukan beberapa permasalahan kualitas data yang menjadi tantangan dalam proses analisis. Terdapat nilai kosong (missing value), terutama pada atribut Profesi, yang berpotensi mengganggu analisis segmentasi pelanggan. Selain itu, beberapa atribut numerik seperti Umur, Pengalaman Pekerjaan, dan Annual Income menunjukkan kemungkinan adanya nilai yang tidak realistis atau tidak konsisten, sehingga diperlukan proses pemeriksaan serta pembersihan data sebelum analisis dilakukan.
#
# Keterbatasan lain yang dihadapi adalah tidak tersedianya atribut waktu, sehingga analisis perubahan atau tren perilaku pelanggan dari waktu ke waktu tidak dapat dilakukan. Selain itu, Spending Score merupakan nilai yang ditentukan oleh pihak toko berdasarkan penilaian internal, sehingga bersifat subjektif dan belum sepenuhnya merepresentasikan nilai transaksi aktual. Dataset ini juga hanya mencakup pelanggan yang memiliki kartu keanggotaan, sehingga hasil analisis belum dapat menggambarkan keseluruhan populasi pelanggan toko secara menyeluruh.

# %% [markdown]
# ###**Analytic Goals**

# %% [markdown]
# dari tujuan bisnis yang sudah ditetapkan, yaitu meningkatkan pendapatan toko dengan memanfaatkan data pelanggan. Pada tahap ini, tujuan bisnis dijabarkan menjadi target analisis yang lebih jelas dan terukur supaya proses pengolahan data dapat dilakukan secara sistematis dan tepat sasaran. Selain itu, hasil dari tahap ini akan menjadi acuan dalam menentukan metode analisis serta jenis visualisasi yang sesuai. Berikut adalah tujuan analisis dalam proyek ini:
#
# 1.	Menjaga kualitas data pelanggan dengan mengatasi nilai kosong (missing value) pada atribut Profesi, serta memeriksa kembali data numerik seperti usia, pengalaman kerja, dan pendapatan tahunan agar data yang digunakan benar-benar valid dan siap dianalisis.
#
# 2.	Menggali karakteristik pelanggan dengan tingkat pengeluaran tinggi berdasarkan faktor demografis dan ekonomi, seperti usia, pendapatan, profesi, dan jumlah anggota keluarga.
#
# 3.	Mengkaji hubungan antara pendapatan tahunan, usia, dan pengalaman kerja terhadap Spending Score untuk mengetahui faktor mana yang paling berpengaruh terhadap tingginya pengeluaran pelanggan.
#
# 4.	Mengelompokkan pelanggan berdasarkan tingkat pengeluaran dan karakteristiknya guna mengetahui segmen pelanggan yang memiliki potensi terbesar dalam meningkatkan pendapatan toko.
#
# 5.	Menyediakan landasan analitis sebagai bahan pertimbangan dalam pengambilan keputusan bisnis, terutama dalam menentukan kelompok pelanggan yang perlu diprioritaskan untuk dipertahankan maupun ditingkatkan kontribusinya.

# %% [markdown]
# ###**Project Plan**

# %% [markdown]
# #### **1. Data Understanding**
#
# Tahap awal dilakukan untuk memahami struktur dan karakteristik dataset pelanggan. Proses ini mencakup identifikasi jumlah data, tipe variabel, serta distribusi atribut seperti usia, pendapatan tahunan, dan Spending Score.
#
# Selain itu, dilakukan pemeriksaan terhadap kemungkinan adanya missing values dan outlier yang dapat memengaruhi hasil analisis.
#
# #### **2. Data Preparition**
#
# Pada tahap ini dilakukan pembersihan dan persiapan data agar siap digunakan dalam analisis. Kegiatan yang dilakukan meliputi:
#
# * Penanganan nilai kosong pada atribut Profesi menggunakan metode pengelompokan kategori.
#
# * Perbaikan nilai yang tidak realistis pada variabel usia, pengalaman kerja, dan pendapatan tahunan.
#
# * normalisasi data numerik apabila diperlukan untuk analisis lanjutan.
#
# Untuk menghasilkan dataset yang bersih, konsisten, dan valid sehingga dapat digunakan sebagai dasar pengambilan keputusan.
#
# #### **3. Analisis & Visualisasi Data**
#
# Setelah data bersih, dilakukan analisis eksploratif untuk mengidentifikasi pola dan hubungan antar variabel. Analisis ini meliputi:
#
# * Hubungan antara pendapatan, usia, dan pengalaman kerja terhadap Spending Score.
#
# * Pola pengeluaran pelanggan berdasarkan karakteristik demografis.
#
# * Penggunaan statistik deskriptif serta visualisasi seperti scatter plot, bar chart, dan boxplot untuk memperjelas pola data.
#
# ####**4. Insight & Action**
#
# Berdasarkan hasil analisis dan visualisasi yang telah dilakukan, teridentifikasi adanya segmen pelanggan dengan Spending Score tinggi yang dipengaruhi oleh faktor pendapatan, usia, serta karakteristik demografis tertentu. Temuan ini menunjukkan bahwa segmen tersebut memberikan kontribusi besar terhadap pendapatan perusahaan. Oleh karena itu, perusahaan perlu mengarahkan strategi pemasaran dan promosi secara lebih terfokus pada kelompok pelanggan berpotensi tinggi tersebut. Di sisi lain, diperlukan pula strategi yang tepat untuk meningkatkan minat dan tingkat pengeluaran pada segmen pelanggan lainnya agar pertumbuhan pendapatan dapat tercapai secara lebih merata dan berkelanjutan.

# %% [markdown]
# ##**DATA UNDERSTANDING**

# %% [markdown]
# ### **Struktur Data**

# %%
file = '/content/drive/MyDrive/POSTEST1_AVD/Customers.csv'
df = pd.read_csv(file)
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %% [markdown]
# #### Informasi Dasar

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 2000 Baris dan 8 Kolom

# %% [markdown]
# #### Informasi Lanjut

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              2000 non-null   int64
#  1   Gender                  2000 non-null   object
#  2   Age                     2000 non-null   int64
#  3   Annual Income ($)       2000 non-null   int64
#  4   Spending Score (1-100)  2000 non-null   int64
#  5   Profession              1965 non-null   object
#  6   Work Experience         2000 non-null   int64
#  7   Family Size             2000 non-null   int64
# dtypes: int64(6), object(2)
# memory usage: 125.1+ KB

# %% [markdown]
# 1. **CustomerID:**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: ID Pelanggan unik
#
# 2. **Gender:**
#       Jumlah baris: 2000
#       Tipe data: object
#       Deskripsi: Jenis Kelamin Pelanggan
#
# 3. **Age:**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: Usia Pelanggan
#
# 4. **Annual Income:**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: Pendapatan Tahunan dalam dolar
#
# 5. **Spending Score (1-100):**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: Skor Pengeluaran Pelanggan (1–100)
#
# 6. **Profession:**
#       Jumlah baris: 1965
#       Tipe data: object
#       Deskripsi: Pekerjaan Pelanggan
#
# 7. **Work Experience:**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: Pengalaman Kerja dalam tahun
#
# 8. **Family Size:**
#       Jumlah baris: 2000
#       Tipe data: int64
#       Deskripsi: Jumlah anggota keluarga

# %% [markdown]
# ### **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#          CustomerID  Gender          Age  Annual Income ($)  \
# count   2000.000000    2000  2000.000000        2000.000000
# unique          NaN       2          NaN                NaN
# top             NaN  Female          NaN                NaN
# freq            NaN    1186          NaN                NaN
# mean    1000.500000     NaN    48.960000      110731.821500
# std      577.494589     NaN    28.429747       45739.536688
# min        1.000000     NaN     0.000000           0.000000
# 25%      500.750000     NaN    25.000000       74572.000000
# 50%     1000.500000     NaN    48.000000      110045.000000
# 75%     1500.250000     NaN    73.000000      149092.750000
# max     2000.000000     NaN    99.000000      189974.000000
#
#         Spending Score (1-100) Profession  Work Experience  Family Size
# count              2000.000000       1965      2000.000000  2000.000000
# unique                     NaN          9              NaN          NaN
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris pelanggan adalah 2000. Maka dapat disimpulkan:
# * Kolom Profession hilang 35 data (2000 - 1965)
#
# Kesimpulan: Kolom Profession mengandung missing values, sementara kolom lainnya sudah lengkap (2000 data).
#
#
# ---
#
#
# 2. Mean vs Median (Distribusi Data)
#
# * Kolom Age
#   * Mean = 48,96
#   * Median = 48
#
#   Nilai rata-rata mendekati median, menunjukkan distribusi usia cukup simetris, meskipun terdapat beberapa usia ekstrem (0 atau 99).
#
# * Kolom Annual Income ($)
#   * Mean = 110.731,82
#   * Median = 110.045
#
#   Nilai rata-rata sedikit lebih besar dari median, menunjukkan adanya beberapa individu dengan pendapatan sangat tinggi (outlier), namun mayoritas pendapatan berada di kisaran menengah.
#
# * Kolom Spending Score (1-100)
#   * Mean = 50,96
#   * Median = 50
#
#   Distribusi skor pengeluaran relatif simetris, tidak ada bias signifikan.
#
# * Kolom Work Experience
#   * Mean = 4,10
#   * Median = 3
#
#  Beberapa individu memiliki pengalaman kerja tinggi, tapi mayoritas memiliki pengalaman rendah-sedang.
#
# * Kolom Family Size
#   * Mean = 3,77
#   * Median = 4
#
#   Mayoritas keluarga memiliki 2–5 anggota, distribusi cukup normal.
#
# Kesimpulan: Secara keseluruhan, data sebagian besar simetris, namun beberapa kolom seperti Annual Income dan Work Experience memiliki outlier yang memengaruhi rata-rata.
#
# ---
#
# 3. Min dan Max (Validasi Logika)
#
# * Age
#   * Min = 0
#   * Max = 99
#
# * Annual Income ($)
#   * Min = 0
#   * Max = 189.974
#
# * Spending Score (1-100)
#   * Min = 0
#   * Max = 100
#
# * Work Experience
#   * Min = 0
#   * Max = 17
#
# * Family Size
#   * Min = 1
#   * Max = 9
#
# Kesimpulan:
# * Nilai Age minimum 0 perlu divalidasi, mungkin mewakili bayi atau kesalahan input.
# * Nilai Annual Income ($) minimum 0 menunjukkan beberapa pelanggan tidak memiliki pendapatan.
# * Nilai lain (Spending Score, Work Experience, Family Size) masuk akal dan sesuai ekspektasi.
#
# ---
#
# 4. Standar Deviasi (std) – Variabilitas Data
#
# * Age
#   * Mean = 48,96
#   * Std = 28,43
#
# * Annual Income ($)
#   * Mean = 110.731,82
#   * Std = 45.739,54
#
# * Spending Score (1-100)
#   * Mean = 50,96
#   * Std = 27,93
#
# * Work Experience
#   * Mean = 4,10
#   * Std = 3,92
#
# * Family Size
#   * Mean = 3,77
#   * Std = 1,97
#
# Kesimpulan:
# * Pada kolom Annual Income ($), standar deviasi yang tinggi (45.739) menunjukkan variasi pendapatan yang sangat besar, dipengaruhi oleh beberapa individu dengan pendapatan ekstrem.
#
# * Kolom Age juga memiliki variasi tinggi (28,43), mencakup berbagai kelompok umur.
#
# * Kolom lain seperti Spending Score, Work Experience, Family Size lebih stabil, distribusi relatif merata.

# %% [markdown]
# ### **VERIFIKASI KUALITAS DATA**

# %% [markdown]
# #### **Data Type Check**

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %% [markdown]
# Berdasarkan data diatas, dapat dilihat bahwa kolom CustomerID, Age, Annual Income ($), Spending Score (1–100), Work Experience, dan Family Size sudah menggunakan tipe data numerik (int64) sehingga sesuai untuk dilakukan analisis kuantitatif. Sementara itu, kolom Gender dan Profession bertipe data object, yang sudah tepat karena berisi data kategorikal.
#
# Dengan demikian, seluruh kolom pada dataset ini telah memiliki tipe data yang sesuai dengan karakteristik datanya, sehingga dataset siap untuk digunakan pada tahap analisis dan visualisasi selanjutnya.

# %% [markdown]
# #### **Incosistent Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten.

# %%
print(df['Gender'].unique())
# Out:
# ['Male' 'Female']

# %% [markdown]
# pada kolom **Gender**, diperoleh nilai unik berupa 'Male' dan 'Female'. Hal ini menunjukkan bahwa data pada kolom **Gender** sudah konsisten dan tidak terdapat perbedaan penulisan seperti huruf kapital yang tidak seragam atau ejaan yang berbeda.

# %%
print(df['Profession'].unique())
# Out:
# ['Healthcare' 'Engineer' 'Lawyer' 'Entertainment' 'Artist' 'Executive'
#  'Doctor' 'Homemaker' 'Marketing' nan]

# %% [markdown]
# Pada kolom **Profession**, terdapat beberapa nilai unik seperti Healthcare, Engineer, Lawyer, Entertainment, Artist, Executive, Doctor, Homemaker, dan Marketing. Namun, ditemukan nilai NaN, yang menandakan adanya data kosong atau tidak terisi pada kolom **Profession**.

# %% [markdown]
# #### **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                         Null Ratio in %
# CustomerID                         0.00
# Gender                             0.00
# Age                                0.00
# Annual Income ($)                  0.00
# Spending Score (1-100)             0.00
# Profession                         1.75
# Work Experience                    0.00
# Family Size                        0.00

# %% [markdown]
# **Profession**
# Memiliki missing value sekitar 1,75%, yang dimana jumlah data yang hilang tergolong kecil. Namun demikian, kolom ini tetap perlu ditangani pada tahap data cleaning, baik dengan cara pengisian nilai (imputasi) maupun penghapusan data pada baris tertentu.
#
# Sementara itu, kolom:
#
# * **CustomerID**
# * **Gender**
# * **Age**
# * **Annual Income ($)**
# * **Spending Score (1–100)**
# * **Work Experience**
# * **Family Size**
#
# Tidak memiliki missing value (0%), sehingga tidak memerlukan penanganan khusus.

# %% [markdown]
# ### **Cek Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income ($), Spending Score (1-100), Profession, Work Experience, Family Size]
# Index: []

# %% [markdown]
# Berdasarkan data diatas, dapat diketahui bahwa tidak ditemukan duplicated value pada dataset. Setiap baris data memiliki kombinasi nilai CustomerID, Gender, Age, Annual Income ($), Spending Score (1–100), Profession, Work Experience, dan Family Size yang unik.

# %% [markdown]
# ### **Cek Outliers**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Akan tetapi memang tidak semua kolom perlu kita tangani, kita harus tetap melihat dan memahami tujuan dari setiap kolom yang ada di dataset.
#
# Dan terlihat kolom:
#
# * **Work Experience**
# Dengan persentase sekitar 0,25%
#
# Sementara itu, kolom:
# * **CustomerID**
# * **Age**
# * **Annual Income ($)**
# * **Spending Score (1–100)**
# * **Family Size**
#
# Memiliki persentase outlier sebesar 0%, sehingga tidak memerlukan penanganan khusus.

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                   Persentase Outliers
# CustomerID                             0.00
# Age                                    0.00
# Annual Income ($)                      0.00
# Spending Score (1-100)                 0.00
# Work Experience                        0.25
# Family Size                            0.00

# %% [markdown]
# ## **EDA**

# %% [markdown]
# ### **Comparison(Perbandingan)**

# %%
penjualan_berdasarkan_gender = df.groupby('Gender')['Spending Score (1-100)'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=penjualan_berdasarkan_gender.index, y=penjualan_berdasarkan_gender.values, palette='viridis', hue=penjualan_berdasarkan_gender.index, legend=False)
plt.title('Total Penjualan Berdasarkan Market')
plt.xlabel('Market')
plt.ylabel('Total Penjualan')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Aktivitas: Membandingkan rata-rata Spending Score (1–100) berdasarkan Gender.
#
# Tujuan: Mengidentifikasi kelompok gender mana yang memiliki tingkat pengeluaran lebih tinggi serta membandingkan pola belanja pelanggan secara langsung antar gender.
#
# Visualisasi: Bar Chart (Grafik Batang)

# %% [markdown]
# ### **Composition(Komposisi)**

# %%
spending_by_profession = (df.groupby('Profession')['Spending Score (1-100)'].sum().sort_values(ascending=False))
spending_by_profession_top3 = spending_by_profession.head(3)

plt.figure(figsize=(10, 8))
spending_by_profession_top3.plot(kind='pie',autopct='%1.1f%%',startangle=140,colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Profession Teratas Berdasarkan Total Spending Score')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### **Distribution(Distribusi)**

# %% [markdown]
# Menganalisis penyebaran nilai Spending Score (1–100) pada pelanggan.
#
# Tujuan: Melihat apakah mayoritas pelanggan memiliki tingkat pengeluaran rendah, sedang, atau tinggi, serta mendeteksi adanya kecondongan distribusi (skewness) pada perilaku belanja pelanggan.
#
# Visualisasi: Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Spending Score (1-100)'], bins=20, kde=True)
plt.title('Distribusi Penjualan (Sales)')
plt.xlabel('Spending Score (1-100)')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# ### **Relationship/Hubungan**

# %% [markdown]
# Aktivitas: Menganalisis hubungan (korelasi) antara Annual Income ($) dengan Spending Score (1–100).
#
# Tujuan: Mengetahui apakah pelanggan dengan pendapatan lebih tinggi cenderung memiliki tingkat pengeluaran yang lebih tinggi, serta melihat seberapa kuat hubungan antara daya beli dan perilaku belanja pelanggan.
#
# Visualisasi: Heatmap (Correlation Heatmap)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Annual Income ($)', 'Spending Score (1-100)']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Sales dan Profit')
plt.show()

# %% [markdown]
# ## **PERBAIKAN DATA**

# %% [markdown]
# ### **Tipe Data**

# %%
df
# Out:
#       CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0              1    Male   19              15000                      39
# 1              2    Male   21              35000                      81
# 2              3  Female   20              86000                       6
# 3              4  Female   23              59000                      77
# 4              5  Female   31              38000                      40
# ...          ...     ...  ...                ...                     ...
# 1995        1996  Female   71             184387                      40
# 1996        1997  Female   91              73158                      32
# 1997        1998    Male   87              90961                      14
# 1998        1999    Male   77             182109                       4
# 1999        2000    Male   90             110610                      52
#
#          Profession  Work Experience  Family Size
# ...

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income ($)          int64
# Spending Score (1-100)     int64
# Profession                object
# Work Experience            int64
# Family Size                int64
# dtype: object

# %% [markdown]
# Tipe data pada dataset ini sudah sesuai dengan isi datanya. Kolom seperti CustomerID, Age, Annual Income, Spending Score, Work Experience, dan Family Size menggunakan tipe numerik karena berisi angka, sedangkan Gender dan Profession menggunakan tipe object karena berisi kategori. Oleh karena itu, tidak diperlukan perubahan tipe data dan dataset ini.

# %% [markdown]
# ### **Incosistent Values**

# %%
print(df['Gender'].unique())
# Out:
# ['Male' 'Female']

# %%
print(df['Profession'].unique())
# Out:
# ['Healthcare' 'Engineer' 'Lawyer' 'Entertainment' 'Artist' 'Executive'
#  'Doctor' 'Homemaker' 'Marketing' nan]

# %% [markdown]
# Berdasarkan hasil pemeriksaan, tidak ditemukan inconsistent values pada dataset. Hal ini terlihat dari kolom Gender yang hanya berisi Male dan Female dengan penulisan yang konsisten, serta kolom Profession yang juga memiliki penulisan kategori yang seragam. Oleh karena itu, tidak diperlukan penanganan khusus terkait inconsistent values.

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                         Null Ratio in %
# CustomerID                         0.00
# Gender                             0.00
# Age                                0.00
# Annual Income ($)                  0.00
# Spending Score (1-100)             0.00
# Profession                         1.75
# Work Experience                    0.00
# Family Size                        0.00

# %%
df['Profession'] = df['Profession'].fillna(df['Profession'].dropna().mode()[0])

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                         Null Ratio in %
# CustomerID                          0.0
# Gender                              0.0
# Age                                 0.0
# Annual Income ($)                   0.0
# Spending Score (1-100)              0.0
# Profession                          0.0
# Work Experience                     0.0
# Family Size                         0.0

# %% [markdown]
# Berdasarkan hasil pemeriksaan missing values, hanya kolom Profession yang memiliki nilai kosong sebesar 1,75%, sedangkan kolom lainnya tidak memiliki missing values. Karena Profession merupakan data non numerik, penanganan dilakukan dengan mengisi nilai kosong menggunakan modus.

# %% [markdown]
# ### **Duplicated Value**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income ($), Spending Score (1-100), Profession, Work Experience, Family Size]
# Index: []

# %% [markdown]
# Berdasarkan hasil pemeriksaan, tidak ditemukan duplicated values pada dataset. Hal ini menunjukkan bahwa setiap baris data tidak ada data yang terduplikasi. Oleh karena itu, tidak diperlukan penanganan terhadap duplicated value.

# %% [markdown]
# ###**Outlier**

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                   Persentase Outliers
# CustomerID                             0.00
# Age                                    0.00
# Annual Income ($)                      0.00
# Spending Score (1-100)                 0.00
# Work Experience                        0.25
# Family Size                            0.00

# %% [markdown]
# Berdasarkan pemeriksaan outliers, ditemukan outlier pada kolom Work Experience sebesar 0,25%, sedangkan kolom lainnya tidak memiliki outlier. Outlier tersebut tidak dilakukan penanganan karena masih mungkin terjadi secara nyata, misalnya pelanggan dengan pengalaman kerja yang sedikit atau sangat tinggi. Selain itu, jumlahnya sangat kecil sehingga tidak memberikan pengaruh signifikan terhadap data.

# %% [markdown]
# ### **Construct Data**

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size
# 0     Healthcare                1            4
# 1       Engineer                3            3
# 2       Engineer                1            1
# 3         Lawyer                0            2
# 4  Entertainment                2            6

# %%
def kategori_spending(score):
    if score >= 80:
        return 'Tinggi'
    elif score >= 50:
        return 'Sedang'
    else:
        return 'Rendah'

df['Kategori Spending'] = df['Spending Score (1-100)'].apply(kategori_spending)

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income ($)  Spending Score (1-100)  \
# 0           1    Male   19              15000                      39
# 1           2    Male   21              35000                      81
# 2           3  Female   20              86000                       6
# 3           4  Female   23              59000                      77
# 4           5  Female   31              38000                      40
#
#       Profession  Work Experience  Family Size Kategori Spending
# 0     Healthcare                1            4            Rendah
# 1       Engineer                3            3            Tinggi
# 2       Engineer                1            1            Rendah
# 3         Lawyer                0            2            Sedang
# 4  Entertainment                2            6            Rendah

# %% [markdown]
# Pada tahap construct data, dibuat kolom baru bernama Kategori Spending berdasarkan nilai Spending Score (1–100) untuk mengelompokkan pelanggan menjadi kategori Rendah, Sedang, dan Tinggi. Karena mempermudah identifikasi segmen pelanggan yang memiliki tingkat pengeluaran tinggi sesuai dengan tujuan analisis, yaitu meningkatkan pendapatan toko dengan menargetkan pelanggan. Dengan adanya kategori ini, proses analisis menjadi lebih jelas dan memudahkan dalam pengambilan keputusan strategi pemasaran.

# %% [markdown]
# ### **Data Reduction**

# %%
df = df.drop('Family Size', axis=1)

# %% [markdown]
# Pada tahap data reduction, kolom Family Size dihapus karena tidak berkaitan langsung dengan tujuan analisis, yaitu meningkatkan pendapatan toko dengan mengidentifikasi pelanggan yang memiliki tingkat pengeluaran tinggi. Jumlah anggota keluarga tidak secara langsung menunjukkan seberapa besar pelanggan mengeluarkan uang di toko.

# %%
df.to_excel('Chechpoint 4.xlsx', index = False)

# %% [markdown]
# ### **Bar Chart**

# %%
VARIABEL = df.groupby('Profession')['Spending Score (1-100)'].mean().sort_values(ascending=False).head(5)

plt.figure(figsize=(10, 6))
plt.bar(VARIABEL.index, VARIABEL.values, color='skyblue')
plt.xlabel('Profession')
plt.ylabel('Average Spending Score')
plt.title('Rata-rata Spending Score Berdasarkan Profesi')
plt.xticks(rotation=0, ha='center')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Dari grafik terlihat bahwa pelanggan yang bekerja di bidang Entertainment punya rata-rata Spending Score paling tinggi. Setelah itu disusul oleh Artist dan Doctor. Artinya, pelanggan dari profesi tersebut cenderung lebih sering atau lebih banyak melakukan pengeluaran di toko dibandingkan profesi lain seperti Healthcare dan Executive. Walaupun selisihnya tidak terlalu jauh, kelompok profesi ini tetap bisa dianggap sebagai pelanggan yang cukup potensial dalam memberikan kontribusi terhadap pendapatan toko
#
# **Action**
#
# Berdasarkan hal tersebut, toko bisa lebih memfokuskan strategi pemasaran kepada pelanggan dari profesi Entertainment, Artist, dan Doctor, misalnya dengan memberikan promo khusus, program member eksklusif, atau penawaran produk yang lebih premium. Selain itu, untuk pelanggan dari profesi lain seperti Healthcare dan Executive, toko bisa mencoba membuat promo yang lebih menarik agar mereka juga terdorong untuk meningkatkan pengeluaran mereka di toko. Dengan begitu, pendapatan toko bisa meningkat dari berbagai segmen pelanggan.

# %% [markdown]
# ### **Pie Chart**

# %%
plt.figure(figsize=(10, 6))
plt.pie(df['Profession'].value_counts(),
        labels=df['Profession'].value_counts().index,
        autopct='%1.1f%%',
        colors=['lightcoral', 'lightblue', 'lightgreen', 'gold'])

plt.title('Proporsi Pelanggan Berdasarkan Profesi')
plt.show()

# %% [markdown]
# **Insight**
#
# Dari pie chart terlihat bahwa profesi Artist memiliki proporsi pelanggan paling besar yaitu sekitar 32,4% dari total pelanggan. Setelah itu disusul oleh Healthcare sekitar 16,9% dan Entertainment sekitar 11,7%. Hal ini menunjukkan bahwa sebagian besar pelanggan toko berasal dari beberapa profesi tersebut, terutama Artist yang jumlahnya jauh lebih dominan dibandingkan profesi lainnya seperti Marketing, Homemaker, atau Lawyer yang persentasenya lebih kecil.
#
# **Action**
#
# Berdasarkan hasil tersebut, toko bisa lebih menyesuaikan strategi pemasaran dengan profesi yang jumlah pelanggannya paling banyak, terutama Artist, Healthcare, dan Entertainment. Misalnya dengan membuat promo atau penawaran produk yang sesuai dengan kebutuhan atau gaya hidup mereka. Selain itu, toko juga bisa mencoba menarik lebih banyak pelanggan dari profesi yang jumlahnya masih sedikit dengan promosi yang lebih menarik agar komposisi pelanggan menjadi lebih seimbang dan peluang peningkatan pendapatan toko semakin besar.

# %% [markdown]
# ### **Line Chart**

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Spending Score (1-100)'], bins=20, kde=True, color='blue')
plt.title('JUDUL')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # **Insight**
#
# Dari histogram terlihat bahwa nilai Spending Score pelanggan tersebar cukup merata dari nilai rendah hingga tinggi. Namun, terlihat bahwa cukup banyak pelanggan berada pada rentang nilai menengah hingga tinggi, sekitar skor 40 sampai 70. Hal ini menunjukkan bahwa sebagian besar pelanggan memiliki tingkat pengeluaran yang cukup aktif di toko, meskipun masih ada pelanggan dengan Spending Score rendah yang kemungkinan jarang berbelanja atau mengeluarkan sedikit uang.
#
# # **Action**
#
# Berdasarkan pola tersebut, toko bisa fokus mempertahankan pelanggan dengan Spending Score menengah hingga tinggi melalui program loyalitas, diskon khusus, atau penawaran produk yang menarik agar mereka tetap sering berbelanja. Selain itu, untuk pelanggan dengan Spending Score rendah, toko bisa memberikan promo atau penawaran khusus agar mereka lebih tertarik untuk meningkatkan pengeluaran mereka di toko. Dengan cara ini, toko dapat meningkatkan pendapatan dari berbagai kelompok pelanggan.

# %% [markdown]
# ### **Box Plot**

# %%
VARIABEL1 = df['Profession'].value_counts().head(5).index
VARIABEL2 = df[df['Profession'].isin(VARIABEL1)]

plt.figure(figsize=(12, 7)) # Ukuran figure
VARIABEL2.boxplot(column='Spending Score (1-100)', by='Profession', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('JUDUL', fontsize=16) # Judul
plt.xlabel('X', fontsize=12) # X Keterangan
plt.ylabel('Y', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **ScatterPlot**

# %%
plt.figure(figsize=(10, 6)) # Ukuran
sns.scatterplot(x='Annual Income ($)', y='Spending Score (1-100)', hue='Profession', data=df)
plt.title('Hubungan antara Annual Income ($) dan Spending Score (1-100) ') # Judul
plt.xlabel('Annual Income ($)') # X Keterangan
plt.ylabel('Spending Score (1-100)') # Y Keterangan
plt.legend(title='KET.KOTAK KECIL') # Keterangan dalam kotak kecil
plt.show()

# %% [markdown]
# **Action**
#
# Berdasarkan grafik hubungan antara Annual Income dan Spending Score, terlihat bahwa penyebaran pelanggan cukup merata pada berbagai tingkat pendapatan dan tingkat pengeluaran. Hal ini menunjukkan bahwa pelanggan dengan pendapatan tinggi tidak selalu memiliki tingkat pengeluaran yang tinggi, dan sebaliknya terdapat juga pelanggan dengan pendapatan yang lebih rendah namun memiliki Spending Score yang cukup tinggi. Selain itu, profesi pelanggan juga tersebar di berbagai titik pada grafik tanpa pola yang jelas, sehingga dapat disimpulkan bahwa profesi bukan merupakan faktor utama yang mempengaruhi perilaku pengeluaran pelanggan.
#
# **Action**
#
# toko dapat melakukan segmentasi pelanggan berdasarkan perilaku pengeluaran (Spending Score) dan tingkat pendapatan (Annual Income). Pelanggan dengan pendapatan tinggi dan Spending Score tinggi dapat dijadikan target utama untuk program loyalitas atau penawaran produk premium. Sementara itu, pelanggan dengan pendapatan tinggi tetapi Spending Score rendah dapat menjadi sasaran strategi pemasaran yang lebih personal, seperti promosi khusus atau rekomendasi produk, agar dapat meningkatkan tingkat pengeluaran mereka. Dengan pendekatan ini, toko dapat membuat strategi pemasaran dan meningkatkan potensi pendapatan dari berbagai segmen pelanggan.

# %% [markdown]
# ### **Bubble Chart**

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(
    x='Annual Income ($)', y='Spending Score (1-100)', size='Work Experience', hue='Kategori Spending', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Hubungan Annual Income dan Spending Score (Ukuran: Work Experience, Warna: Kategori Spending)', fontsize=16)
plt.xlabel('Annual Income ($)', fontsize=12)
plt.ylabel('Spending Score (1-100)', fontsize=12)
plt.grid(True)
plt.legend(title='Kategori Spending', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight**
#
# Berdasarkan grafik yang menunjukkan hubungan antara Annual Income dan Spending Score, dengan ukuran titik yang menggambarkan Work Experience serta warna yang menunjukkan kategori spending, terlihat bahwa pelanggan terbagi ke dalam tiga kelompok pengeluaran yaitu rendah, sedang, dan tinggi. Pelanggan dengan kategori spending rendah tidak hanya berasal dari pendapatan rendah, tetapi juga muncul pada pelanggan dengan pendapatan yang cukup tinggi. Hal ini menunjukkan bahwa pendapatan yang tinggi tidak selalu berarti pengeluaran yang tinggi. Selain itu, pelanggan dengan spending sedang dan tinggi juga tersebar pada berbagai tingkat pendapatan, sehingga dapat disimpulkan bahwa pola pengeluaran pelanggan kemungkinan dipengaruhi oleh faktor lain seperti kebiasaan berbelanja atau preferensi pribadi
#
# **Action**
#
# toko dapat melakukan segmentasi pelanggan berdasarkan kategori spending agar strategi pemasaran bisa lebih tepat sasaran. Pelanggan dengan spending tinggi dapat dipertahankan dengan memberikan program loyalitas, penawaran khusus, atau produk premium agar mereka tetap aktif berbelanja. Untuk pelanggan dengan spending sedang, toko dapat memberikan promo tambahan atau rekomendasi produk agar mereka terdorong meningkatkan jumlah pembelian. Sedangkan pelanggan dengan spending rendah, khususnya yang memiliki pendapatan tinggi, dapat menjadi target promosi yang lebih personal atau kampanye pemasaran yang lebih menarik agar mereka terdorong untuk meningkatkan frekuensi maupun nilai pembelian. Dengan pendekatan ini, toko dapat memaksimalkan potensi pendapatan dari setiap segmen pelanggan.

# %% [markdown]
# ### **Heatmap**

# %%
plt.figure(figsize=(8, 6))

sns.heatmap(
    data=df[['Age', 'Annual Income ($)', 'Work Experience', 'Spending Score (1-100)']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f'
)

plt.title('Korelasi Antar Variabel Pelanggan')

plt.show()

# %% [markdown]
# **Insight**
#
# Berdasarkan heatmap terlihat bahwa hubungan antara Spending Score dengan variabel lain seperti Age, Annual Income, dan Work Experience tergolong sangat lemah. Nilai korelasinya mendekati 0, misalnya hubungan antara Annual Income dan Spending Score hanya sekitar 0.02 yang berarti hubungan antara mereka lemah, serta Age dengan Spending Score sekitar -0.04. Hal ini menunjukkan bahwa tidak ada hubungan yang kuat antara mereka, maupun pengalaman kerja dengan tingkat pengeluaran pelanggan. Dengan kata lain, pelanggan dengan pendapatan tinggi belum tentu memiliki pengeluaran tinggi, dan pelanggan dengan pendapatan lebih rendah juga bisa memiliki Spending Score yang tinggi.
#
# **Action**
#
# Karena hubungan antar variabel tersebut tergolong lemah, toko sebaiknya tidak hanya mengandalkan faktor seperti usia, pendapatan, atau pengalaman kerja dalam menentukan target pemasaran. Sebaliknya, toko bisa lebih fokus pada perilaku pengeluaran pelanggan, seperti kategori Spending (Rendah, Sedang, Tinggi). Selain itu, toko dapat membuat strategi seperti promo khusus, program loyalitas, atau rekomendasi produk untuk mendorong pelanggan dengan Spending Score rendah atau sedang agar meningkatkan pengeluaran mereka di toko. Dengan begitu, potensi peningkatan pendapatan toko bisa lebih maksimal.
